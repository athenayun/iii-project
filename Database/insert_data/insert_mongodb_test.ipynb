# %%
#!sudo apt-get update && sudo apt-get intall -y mariadb-server
# Out:
# 'sudo' 不是內部或外部命令、可執行的程式或批次檔。

# %%
# !pip install PyMySQL

# %%
# !pip install peewee
# Out:
# ...
#   Using cached peewee-2.10.2.tar.gz
# ...
#   Running setup.py bdist_wheel for peewee: started
#   Running setup.py bdist_wheel for peewee: finished with status 'done'
#   Stored in directory: C:\Users\Java\AppData\Local\pip\Cache\wheels\2e\30\4e\4c631faaef29e0406d6c1470258f99e5bdfd394a680c216ff6
# Successfully built peewee
# ...

# %%
# !pip install Pymongo

# %%
import pymongo
from pymongo import MongoClient

# %%
client = MongoClient('localhost', 27017)

# %%
client
# Out:
# MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True)

# %%
files
# files = list
# Out:
# ['D:\\project\\urcosme\\users\\100027.json',
#  'D:\\project\\urcosme\\users\\100102.json',
#  'D:\\project\\urcosme\\users\\100109.json',
#  'D:\\project\\urcosme\\users\\100113.json',
#  'D:\\project\\urcosme\\users\\10012.json',
#  'D:\\project\\urcosme\\users\\100137.json',
#  'D:\\project\\urcosme\\users\\100156.json',
#  'D:\\project\\urcosme\\users\\10018.json',
#  'D:\\project\\urcosme\\users\\100185.json',
#  'D:\\project\\urcosme\\users\\100218.json',
#  'D:\\project\\urcosme\\users\\100230.json',
#  'D:\\project\\urcosme\\users\\100270.json',
#  'D:\\project\\urcosme\\users\\100275.json',
#  'D:\\project\\urcosme\\users\\10028.json',
#  'D:\\project\\urcosme\\users\\100305.json',
#  'D:\\project\\urcosme\\users\\100314.json',
#  'D:\\project\\urcosme\\users\\100391.json',
#  'D:\\project\\urcosme\\users\\100393.json',
#  'D:\\project\\urcosme\\users\\100394.json',
#  'D:\\project\\urcosme\\users\\100479.json',
#  'D:\\project\\urcosme\\users\\100480.json',
# ...

# %% [markdown]
# # mongo_table_frame
#
# ## keys = ['age','buylist','skin_condition','user_id']
#
# ## in buy_list = ['唇膏', '眉筆', '眼線筆', '粉底液']

# %%
import glob
import pprint
import json
import codecs

db = client['project']
collection = db['users']

files = glob.glob('D:\\project\\urcosme\\users\\*.json')


for i in files:
    with codecs.open(i,'r','utf-8')as file :
        ff = json.load(file)
        ff_dict = json.dumps(ff)
        #pprint.pprint(ff)
        
        db.users.insert_one(ff)

# %%
# testing
db2 = client['test']
collection2 = db['users']
new_posts = [{"author": "Mike","text": "Another post!","tags": ["bulk", "insert"]},
{"author": "Eliot","title": "MongoDB is fun","text": "and pretty easy too!"}]

# must use a dictionary to insert ; not json object

db2.collection2.insert_many(new_posts)
